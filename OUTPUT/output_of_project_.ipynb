# %%
from IPython.display import Image, display

# List of image paths
image_paths = ['/content/input.png', '/content/result.png']

# Display each image
for image_path in image_paths:
    display(Image(image_path))
